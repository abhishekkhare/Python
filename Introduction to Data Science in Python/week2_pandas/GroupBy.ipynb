# %%
import pandas as pd

# %%
census_df = pd.read_csv('census.csv')
census_df.head()
counties_df = census_df[census_df['SUMLEV'] == 50]
counties_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
sorted_Counties_df = counties_df.sort_values(by=['STNAME','CENSUS2010POP'],ascending=False)
sorted_Counties_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 3180      50       4         8     56      21  Wyoming     Laramie County
# 3182      50       4         8     56      25  Wyoming     Natrona County
# 3172      50       4         8     56       5  Wyoming    Campbell County
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3176      50       4         8     56      13  Wyoming     Fremont County
# ...      ...     ...       ...    ...     ...      ...                ...
# 19        50       3         6      1      37  Alabama       Coosa County
# 43        50       3         6      1      85  Alabama     Lowndes County
# 6         50       3         6      1      11  Alabama     Bullock County
# 53        50       3         6      1     105  Alabama       Perry County
# 32        50       3         6      1      63  Alabama      Greene County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
columns_to_keep = ['STNAME',
                   'CTYNAME',
                   'CENSUS2010POP',
                   'SUMLEV']
dfTemp = sorted_Counties_df[columns_to_keep]
dfTemp
# Out:
#        STNAME            CTYNAME  CENSUS2010POP  SUMLEV
# 3180  Wyoming     Laramie County          91738      50
# 3182  Wyoming     Natrona County          75450      50
# 3172  Wyoming    Campbell County          46133      50
# 3188  Wyoming  Sweetwater County          43806      50
# 3176  Wyoming     Fremont County          40123      50
# ...       ...                ...            ...     ...
# 19    Alabama       Coosa County          11539      50
# 43    Alabama     Lowndes County          11299      50
# 6     Alabama     Bullock County          10914      50
# 53    Alabama       Perry County          10591      50
# 32    Alabama      Greene County           9045      50
#
# [3142 rows x 4 columns]

# %%
dfTemp.head(3)
# Out:
#        STNAME          CTYNAME  CENSUS2010POP  SUMLEV
# 3180  Wyoming   Laramie County          91738      50
# 3182  Wyoming   Natrona County          75450      50
# 3172  Wyoming  Campbell County          46133      50

# %%
dfTemp['CENSUS2010POP'].nlargest(5)
# Out:
# 209     9818605
# 624     5194675
# 2667    4092459
# 106     3817117
# 227     3095313
# Name: CENSUS2010POP, dtype: int64

# %%
dfTemp.nlargest(5,'CENSUS2010POP')
# Out:
#           STNAME             CTYNAME  CENSUS2010POP  SUMLEV
# 209   California  Los Angeles County        9818605      50
# 624     Illinois         Cook County        5194675      50
# 2667       Texas       Harris County        4092459      50
# 106      Arizona     Maricopa County        3817117      50
# 227   California    San Diego County        3095313      50

# %%
dfTemp['CENSUS2010POP'].nsmallest(5)
# Out:
# 2717     82
# 560      90
# 2701    286
# 2697    416
# 1684    460
# Name: CENSUS2010POP, dtype: int64

# %%
dfTemp.nsmallest(5,'CENSUS2010POP')
# Out:
#         STNAME         CTYNAME  CENSUS2010POP  SUMLEV
# 2717     Texas   Loving County             82      50
# 560     Hawaii  Kalawao County             90      50
# 2701     Texas     King County            286      50
# 2697     Texas   Kenedy County            416      50
# 1684  Nebraska   Arthur County            460      50

# %%
dfGroupBy = dfTemp.groupby(['STNAME'])
dfGroupBy

# %%
dfGroupBy.get_group('Texas')
# Out:
#      STNAME          CTYNAME  CENSUS2010POP  SUMLEV
# 2667  Texas    Harris County        4092459      50
# 2623  Texas    Dallas County        2368139      50
# 2786  Texas   Tarrant County        1809034      50
# 2581  Texas     Bexar County        1714773      50
# 2793  Texas    Travis County        1024266      50
# ...     ...              ...            ...     ...
# 2722  Texas  McMullen County            707      50
# 2583  Texas    Borden County            641      50
# 2697  Texas    Kenedy County            416      50
# 2701  Texas      King County            286      50
# 2717  Texas    Loving County             82      50
#
# [254 rows x 4 columns]

# %%
top_counties_TX_df = dfGroupBy.get_group('Texas').head(3)
top_counties_TX_df
# Out:
#      STNAME         CTYNAME  CENSUS2010POP  SUMLEV
# 2667  Texas   Harris County        4092459      50
# 2623  Texas   Dallas County        2368139      50
# 2786  Texas  Tarrant County        1809034      50

# %%
top_counties_TX_df.sum()
# Out:
# STNAME                                    TexasTexasTexas
# CTYNAME          Harris CountyDallas CountyTarrant County
# CENSUS2010POP                                     8269632
# SUMLEV                                                150
# dtype: object

# %%
dfGroupBy.head(3)
# Out:
#          STNAME                       CTYNAME  CENSUS2010POP  SUMLEV
# 3180    Wyoming                Laramie County          91738      50
# 3182    Wyoming                Natrona County          75450      50
# 3172    Wyoming               Campbell County          46133      50
# 3137  Wisconsin              Milwaukee County         947735      50
# 3109  Wisconsin                   Dane County         488073      50
# ...         ...                           ...            ...     ...
# 76       Alaska  Fairbanks North Star Borough          97581      50
# 85       Alaska     Matanuska-Susitna Borough          88995      50
# 37      Alabama              Jefferson County         658466      50
# 49      Alabama                 Mobile County         412992      50
# 45      Alabama                Madison County         334811      50
#
# [151 rows x 4 columns]

# %%
top_counties_3 = dfGroupBy.head(3)
top_counties_3
# Out:
#          STNAME                       CTYNAME  CENSUS2010POP  SUMLEV
# 3180    Wyoming                Laramie County          91738      50
# 3182    Wyoming                Natrona County          75450      50
# 3172    Wyoming               Campbell County          46133      50
# 3137  Wisconsin              Milwaukee County         947735      50
# 3109  Wisconsin                   Dane County         488073      50
# ...         ...                           ...            ...     ...
# 76       Alaska  Fairbanks North Star Borough          97581      50
# 85       Alaska     Matanuska-Susitna Borough          88995      50
# 37      Alabama              Jefferson County         658466      50
# 49      Alabama                 Mobile County         412992      50
# 45      Alabama                Madison County         334811      50
#
# [151 rows x 4 columns]

# %%
dfGroupBy3 = top_counties_3.groupby(['STNAME'])
dfGroupBy3

# %%
total_3 = dfGroupBy3.sum()
total_3
# Out:
#                       CENSUS2010POP  SUMLEV
# STNAME
# Alabama                     1406269     150
# Alaska                       478402     150
# Arizona                     5173150     150
# Arkansas                     807152     150
# California                 15924150     150
# Colorado                    1794424     150
# Connecticut                 2673320     150
# Delaware                     897934     150
# District of Columbia         601723      50
# Florida                     5564635     150
# Georgia                     2417795     150
# Hawaii                      1293120     150
# Idaho                        719782     150
# Illinois                    6815061     150
# Indiana                     1754727     150
# Iowa                         807090     150
# Kansas                      1220478     150
# Kentucky                    1196619     150
# Louisiana                   1216552     150
# Maine                        632728     150
# ...

# %%
total_3.loc['Arizona']
# Out:
# CENSUS2010POP    5173150
# SUMLEV               150
# Name: Arizona, dtype: int64

# %%
total_3.sort_values(by='CENSUS2010POP').head(3).index.tolist()
# Out:
# ['Wyoming', 'Vermont', 'North Dakota']

# %%
counties_df = census_df[census_df['SUMLEV'] == 50]
counties_df = counties_df.set_index('CTYNAME')
counties_df
dfTemp = counties_df
dfTemp
# Out:
#                    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME  \
# CTYNAME
# Autauga County         50       3         6      1       1  Alabama
# Baldwin County         50       3         6      1       3  Alabama
# Barbour County         50       3         6      1       5  Alabama
# Bibb County            50       3         6      1       7  Alabama
# Blount County          50       3         6      1       9  Alabama
# ...                   ...     ...       ...    ...     ...      ...
# Sweetwater County      50       4         8     56      37  Wyoming
# Teton County           50       4         8     56      39  Wyoming
# Uinta County           50       4         8     56      41  Wyoming
# Washakie County        50       4         8     56      43  Wyoming
# Weston County          50       4         8     56      45  Wyoming
#
#                    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# CTYNAME
# ...

# %%
dfMax = dfTemp[['POPESTIMATE2010',
                               'POPESTIMATE2011',
                               'POPESTIMATE2012',
                               'POPESTIMATE2013',
                               'POPESTIMATE2014',
                               'POPESTIMATE2015']].max(axis=1)
dfMax
# Out:
# CTYNAME
# Autauga County        55347
# Baldwin County       203709
# Barbour County        27341
# Bibb County           22861
# Blount County         57776
#                       ...
# Sweetwater County     45162
# Teton County          23125
# Uinta County          21102
# Washakie County        8545
# Weston County          7234
# Length: 3142, dtype: int64

# %%
dfMin = dfTemp[['POPESTIMATE2010',
                               'POPESTIMATE2011',
                               'POPESTIMATE2012',
                               'POPESTIMATE2013',
                               'POPESTIMATE2014',
                               'POPESTIMATE2015']].min(axis=1)
dfMin
# Out:
# CTYNAME
# Autauga County        54660
# Baldwin County       183193
# Barbour County        26489
# Bibb County           22512
# Blount County         57373
#                       ...
# Sweetwater County     43593
# Teton County          21297
# Uinta County          20822
# Washakie County        8316
# Weston County          7065
# Length: 3142, dtype: int64

# %%
dfDelta = dfMax-dfMin
dfDelta
# Out:
# CTYNAME
# Autauga County         687
# Baldwin County       20516
# Barbour County         852
# Bibb County            349
# Blount County          403
#                      ...
# Sweetwater County     1569
# Teton County          1828
# Uinta County           280
# Washakie County        229
# Weston County          169
# Length: 3142, dtype: int64

# %%
dfDelta.sort_values(ascending = False).head(1).index.tolist()
# Out:
# ['Harris County']
